# %%
import pandas as pd

# %%
cd ..
# Out:
# /Users/seimandijuliette/Documents/efrei/M2/Deep learning/General

# %%
df = pd.read_csv('cc_bvol_demo.qa.csv')

# %%
df.head(5)
# Out:
#    Unnamed: 0     id                                        ID  CC_area  \
# 0           1  50002  ./Pitt/0050002/session_1/anat_1/abide_cc   674.75
# 1           2  50003  ./Pitt/0050003/session_1/anat_1/abide_cc   620.50
# 2           3  50004  ./Pitt/0050004/session_1/anat_1/abide_cc   617.00
# 3           4  50005  ./Pitt/0050005/session_1/anat_1/abide_cc   524.50
# 4           5  50006  ./Pitt/0050006/session_1/anat_1/abide_cc   655.25
#
#    CC_perimeter  CC_circularity  CC_length     W1      W2      W3  ...  \
# 0        216.77        0.180444       76.5  28.25  135.25   95.50  ...
# 1        196.34        0.202275       73.0  11.50  124.75  112.50  ...
# 2        203.15        0.187880       74.0  22.75  160.25   92.50  ...
# 3        191.32        0.180072       67.5  18.25   79.25   95.25  ...
# 4        206.12        0.193817       77.0  15.00  141.00  103.25  ...
#
#    WISC_IV_CODING_SCALED  WISC_IV_SYM_SCALED  EYE_STATUS_AT_SCAN  \
# ...

# %%
df
# Out:
#       Unnamed: 0     id                                            ID  \
# 0              1  50002      ./Pitt/0050002/session_1/anat_1/abide_cc
# 1              2  50003      ./Pitt/0050003/session_1/anat_1/abide_cc
# 2              3  50004      ./Pitt/0050004/session_1/anat_1/abide_cc
# 3              4  50005      ./Pitt/0050005/session_1/anat_1/abide_cc
# 4              5  50006      ./Pitt/0050006/session_1/anat_1/abide_cc
# ...          ...    ...                                           ...
# 1095        1096  51583       ./SBL/0051583/session_1/anat_1/abide_cc
# 1096        1097  51584       ./SBL/0051584/session_1/anat_1/abide_cc
# 1097        1098  51585       ./SBL/0051585/session_1/anat_1/abide_cc
# 1098        1099  51606  ./MaxMun_a/0051606/session_1/anat_1/abide_cc
# 1099        1100  51607  ./MaxMun_a/0051607/session_1/anat_1/abide_cc
#
#       CC_area  CC_perimeter  CC_circularity  CC_length     W1      W2      W3  \
# ...

# %%
cd abide.cc.bvol-2.20150118/
# Out:
# /Users/seimandijuliette/Documents/efrei/M2/Deep learning/General/abide.cc.bvol-2.20150118

# %%
pwd
# Out:
# '/Users/seimandijuliette/Documents/efrei/M2/Deep learning/General/abide.cc.bvol-2.20150118'

# %%
l = []
for i in df['ID'] :
    l.append(i + ".nii")

# %%
df["path"]  = l

# %%
df
# Out:
#       Unnamed: 0     id                                            ID  \
# 0              1  50002      ./Pitt/0050002/session_1/anat_1/abide_cc
# 1              2  50003      ./Pitt/0050003/session_1/anat_1/abide_cc
# 2              3  50004      ./Pitt/0050004/session_1/anat_1/abide_cc
# 3              4  50005      ./Pitt/0050005/session_1/anat_1/abide_cc
# 4              5  50006      ./Pitt/0050006/session_1/anat_1/abide_cc
# ...          ...    ...                                           ...
# 1095        1096  51583       ./SBL/0051583/session_1/anat_1/abide_cc
# 1096        1097  51584       ./SBL/0051584/session_1/anat_1/abide_cc
# 1097        1098  51585       ./SBL/0051585/session_1/anat_1/abide_cc
# 1098        1099  51606  ./MaxMun_a/0051606/session_1/anat_1/abide_cc
# 1099        1100  51607  ./MaxMun_a/0051607/session_1/anat_1/abide_cc
#
#       CC_area  CC_perimeter  CC_circularity  CC_length     W1      W2      W3  \
# ...

# %%
df['path']= df['path'].str.replace('./','',1)

# %%
df
# Out:
#       Unnamed: 0     id                                            ID  \
# 0              1  50002      ./Pitt/0050002/session_1/anat_1/abide_cc
# 1              2  50003      ./Pitt/0050003/session_1/anat_1/abide_cc
# 2              3  50004      ./Pitt/0050004/session_1/anat_1/abide_cc
# 3              4  50005      ./Pitt/0050005/session_1/anat_1/abide_cc
# 4              5  50006      ./Pitt/0050006/session_1/anat_1/abide_cc
# ...          ...    ...                                           ...
# 1095        1096  51583       ./SBL/0051583/session_1/anat_1/abide_cc
# 1096        1097  51584       ./SBL/0051584/session_1/anat_1/abide_cc
# 1097        1098  51585       ./SBL/0051585/session_1/anat_1/abide_cc
# 1098        1099  51606  ./MaxMun_a/0051606/session_1/anat_1/abide_cc
# 1099        1100  51607  ./MaxMun_a/0051607/session_1/anat_1/abide_cc
#
#       CC_area  CC_perimeter  CC_circularity  CC_length     W1      W2      W3  \
# ...

# %%
df['diagnosis']
# Out:
# 0       autism
# 1       autism
# 2       autism
# 3       autism
# 4       autism
#          ...
# 1095    autism
# 1096    autism
# 1097    autism
# 1098    autism
# 1099    autism
# Name: diagnosis, Length: 1100, dtype: object

# %%
pd.crosstab(df.diagnosis, 'f')
# Out:
# col_0        f
# diagnosis
# autism     529
# control    571

# %%
diag=df['diagnosis']
index_aut=[]
ind_control=[]

for i in range(0,1100):
    if df['diagnosis'][i] == 'autism':
        ind=df['Unnamed: 0'][i]
        index_aut.append(ind)
    if df['diagnosis'][i] == 'control':
        ind=df['Unnamed: 0'][i]
        ind_control.append(ind)

# %%
cd ..
# Out:
# /Users/seimandijuliette/Documents/efrei/M2

# %%
import os.path as op
import os

# %%
pwd = '/Users/seimandijuliette/Documents/efrei/M2/Deep learning/General/abide.cc.bvol-2.20150118'

# %%
import shutil

# %%
for i in index_aut:
    folder_path = df['path'][i]
    rs=folder_path.split('/')
    car=rs[1]
    pth_current= pwd+'/' +folder_path
    futur_dir= 'autism/'+car+'/'
    
    if not op.exists(futur_dir):
        os.makedirs(futur_dir)
        
    shutil.move(pth_current, futur_dir)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/shutil.py in move(src, dst, copy_function)
#     787     try:
# --> 788         os.rename(src, real_dst)
#     789     except OSError:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/seimandijuliette/Documents/efrei/M2/Deep learning/General/abide.cc.bvol-2.20150118/Pitt/0050003/session_1/anat_1/abide_cc.nii' -> 'autism/0050003/abide_cc.nii'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-126-79ca062606b6> in <module>
#       9         os.makedirs(futur_dir)
#      10
# ---> 11     shutil.move(pth_current, futur_dir)
#      12
#      13     #print(images)
#
# ~/anaconda3/lib/python3.8/shutil.py in move(src, dst, copy_function)
#     800             rmtree(src)
# ...

# %%
for i in ind_control:
    folder_path = df['path'][i]
    rs=folder_path.split('/')
    car=rs[1]
    pth_current= pwd+'/' +folder_path
    futur_dir= 'control/'+car+'/'
    
    if not op.exists(futur_dir):
        os.makedirs(futur_dir)
        
    shutil.move(pth_current, futur_dir)
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-140-2992ff7d2393> in <module>
#       9         os.makedirs(futur_dir)
#      10
# ---> 11     shutil.move(pth_current, futur_dir)
#
# ~/anaconda3/lib/python3.8/shutil.py in move(src, dst, copy_function)
#     784         real_dst = os.path.join(dst, _basename(src))
#     785         if os.path.exists(real_dst):
# --> 786             raise Error("Destination path '%s' already exists" % real_dst)
#     787     try:
#     788         os.rename(src, real_dst)
#
# Error: Destination path 'control/0050031/abide_cc.nii' already exists
